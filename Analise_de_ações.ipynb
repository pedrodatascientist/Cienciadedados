# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrodatascientist/Cienciadedados/blob/master/Analise_de_a%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analisando preço de uma ação

# %%
#Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
# !pip install schedule
import schedule 
from datetime import date
import time
# instalando yfinace(de onde será feita a requisição)
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()
# Out:
# ...
# Requirement already up-to-date: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.54)
# ...

# %% [markdown]
# Obtendo dados do mercado

# %%
data_atual = date.today()
ibov = web.get_data_yahoo('^BVSP', start= '2020-03-01', end=data_atual)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov['Close'].plot(figsize=(10,8), color='red');
ibov['Open'].plot(figsize=(10,8));
plt.title('Abertura vs Fechamento');
plt.legend();

# %%
ibov['Open'].plot(figsize=(10,8));
plt.title('Pontos de abertura');

# %%
Graf = sns.relplot(x='Open', y='Close', data=ibov, hue='Open');
Graf.fig.set_size_inches(20,8)

# %%
ibov.describe()
# Out:
#                 Open           High  ...      Adj Close        Volume
# count    6647.000000    6647.000000  ...    6647.000000  6.647000e+03
# mean    37842.157271   38235.956564  ...   37849.188576  5.358621e+06
# std     28054.078910   28288.808422  ...   28060.812646  2.118195e+07
# min        23.700001      24.200001  ...      23.700001  0.000000e+00
# 25%     11433.500000   11541.000000  ...   11401.500000  0.000000e+00
# 50%     37750.000000   38342.000000  ...   37777.000000  0.000000e+00
# 75%     59039.000000   59527.500000  ...   59072.500000  3.249550e+06
# max    119528.000000  119593.000000  ...  119528.000000  2.322653e+08
#
# [8 rows x 6 columns]
